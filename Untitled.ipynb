# %%
import sys;import os;from IPython.display import Image, display
wd = os.getcwd()+"/pics"
for i in sorted(os.listdir(wd)):
    filename=wd+"/"+i
    print(filename)
    display(Image(filename=filename))
# Out:
# /home/t/pymol/FractionContacts/pics/NNTXD.1.png
# /home/t/pymol/FractionContacts/pics/NNTXD.2.png
# /home/t/pymol/FractionContacts/pics/NNTXD.3.png
# /home/t/pymol/FractionContacts/pics/NNTXD.4.png
# /home/t/pymol/FractionContacts/pics/NNTXD.5.png
# /home/t/pymol/FractionContacts/pics/NNXD.1.png
# /home/t/pymol/FractionContacts/pics/NNXD.2.png
# /home/t/pymol/FractionContacts/pics/NNXD.3.png
# /home/t/pymol/FractionContacts/pics/NNXD.4.png
# /home/t/pymol/FractionContacts/pics/NNXD.5.png
# /home/t/pymol/FractionContacts/pics/NTXD.1.png
# /home/t/pymol/FractionContacts/pics/NTXD.2.png
# /home/t/pymol/FractionContacts/pics/NTXD.3.png
# /home/t/pymol/FractionContacts/pics/NTXD.4.png
# /home/t/pymol/FractionContacts/pics/NTXD.5.png
# /home/t/pymol/FractionContacts/pics/NXD.1.png
# /home/t/pymol/FractionContacts/pics/NXD.2.png
# /home/t/pymol/FractionContacts/pics/NXD.3.png
# /home/t/pymol/FractionContacts/pics/NXD.4.png
# /home/t/pymol/FractionContacts/pics/NXD.5.png
